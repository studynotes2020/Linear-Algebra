# %% [markdown]
# # Review Problems
#
# Given $$Ax =\begin{bmatrix}1 \\ 0\\ 0 \end{bmatrix}$$ has no solution
#
# $$Ax =\begin{bmatrix}0 \\ 1\\ 0 \end{bmatrix}$$ has 1 solution
#
# What can we tell about m (rows), n (columns) and r (rank)?
#
# m = 3. No solution means some rows of the matrix are combinations of other rows, r < m
#
# Has 1 solution means nullspace only has zero vector. r = n. columns are independent
#
# m = 3 > n = r
#
# Give an example of A
#
# $$A = \begin{bmatrix}0 \\ 1\\ 0 \end{bmatrix}$$
#
# m is 3 greater than n and r which is 1
#
# If we want matrix more than 1 column
#
# $$A = \begin{bmatrix}0 & 0 \\ 1 & 0\\ 0 & 1 \end{bmatrix}$$
#
# m = 3 greater than n and r which is 2

# %% [markdown]
# ## True of False
#
# $$A = \begin{bmatrix}0 & 0 \\ 1 & 0\\ 0 & 1 \end{bmatrix}
# \quad A^TA = \begin{bmatrix}1 & 0\\ 0 & 1 \end{bmatrix}
# \quad AA^T = \begin{bmatrix}0 & 0 & 0\\0 & 1 & 0\\0 & 0 & 1 \end{bmatrix}$$
#
# 1. $det(A^TA) = det(AA^T)$?
# Invertible for $A^TA$ but not invertible for $AA^T$. So, false
# If the matrix A is square, this is true. Because then we can split into $det(A^T).det(A)$
#
#
# 2. $A^TA$ is invertible?
# This is invertible if r = n -> independent columns of A. So, true
#
#
# 3. $AA^T$ is positive definite?
# 3xn multiply nx3 = 3x3. The rank will be the same as rank A, so r = 2. But matrix of 3x3 with rank 2 not positive definite. First row all zero also shows not positive definite and non-invertible So, false. It is true for semi-definite
#
#
#
# ## Prove
#
# $A^Ty = c$ has at least 1 solution (in fact infinitely many solutions) for every c
#
# $A^T$ is nxm. It has at least 1 solution, because n = r (full row rank). A has independent columns, after transpose it has independent rows.
#
# How do we know it has infinitely many solutions?
#
# $dim N(A^T) = m-r > 0$. There are m-r free variables
#
#
# ## Suppose
#
# $$A = \begin{bmatrix}\vec v_1 & \vec v_2 & \vec v_3 \end{bmatrix}$$
#
# (a) Solve $Ax = v_1 - v_2 + v_3$
#
# $$x = \begin{bmatrix}1\\ -1 \\ 1 \end{bmatrix}$$
#
# (b) Suppose $v_1 - v_2 + v_3 = 0$
#
# The solution is unique when nullspace only has zero vector. if $v_1 - v_2 + v_3 = 0$, then $x$ is in the $N(A)$, so the solutions are never unique
#
# (c) If $v_1, v_2, v_3$ are orthonormal, what combination of $v_1, v_2$ is closest to $v_3$. Answer $0v_1 + 0v_2$, (0, 0), the xy plane is the closest to the z-axis

# %% [markdown]
# ## Markov matrix
#
# $$A = \begin{bmatrix}.2 & .4 & .3 \\ .4 & .2 & .3 \\ .4 & .4 & .4 \end{bmatrix}$$
#
# $col1 + col2 = 2(col3)$
#
# $\lambda = 0, 1, -.2$
#
# 0 because matrix is singular. 1 because it is markov matrix. then we get the third one from trace
#
# $$u_k = A^k \begin{bmatrix}0 \\ 10\\ 0 \end{bmatrix} = c_1 \lambda_1^k x_1 + c_2 \lambda_2^k x_2 + c_3 \lambda_3^k x_3$$
#
# At infnity, $\lambda_1, \lambda_3 \approx 0$
#
# $$u_{\infty} = c_2 x_2$$
#
# So, we need to find $c_2, x_2$
#
# When $\lambda = 1$, $$A-I = \begin{bmatrix}-.8 & .4 & .3 \\ .4 & -.8 & .3\\ .4 & .4 & -.6 \end{bmatrix}$$
#
# $$(A-I)x_2 = 0$$
#
# Then we get $\vec x_2 = \begin{bmatrix}3\\ 3\\ 4 \end{bmatrix}$
#
# The total population is the same, so $c_2 = 1$
#
# $$u_{\infty} = \begin{bmatrix}3\\ 3\\ 4 \end{bmatrix}$$

# %% [markdown]
# ## 2x2
#
# 1. Project onto $a = \begin{bmatrix}4 \\ -3 \end{bmatrix}$
#
# $$P = \frac{aa^T}{a^Ta}$$
#
# 2. Giving eigenvalue and eigenvector pair. What is the matrix A
#
# $$\lambda_1 = 0, \quad x_1 = \begin{bmatrix}1 \\ 2 \end{bmatrix}$$
#
# $$\lambda_2 = 3, \quad x_2 = \begin{bmatrix}2 \\ 1 \end{bmatrix}$$
#
# We can construct eigenvector matrix and eigenvalue matrix
#
# $$A = S\Lambda S^{-1}$$
#
# $$A = \begin{bmatrix}1 & 2 \\ 2 & 1 \end{bmatrix} \begin{bmatrix}0 & 0\\ 0 & 3 \end{bmatrix} \begin{bmatrix}1 & 2 \\ 2 & 1 \end{bmatrix}^{-1}$$
#
#
# ## Find $A$ such that
#
# $$A \neq B^TB$$ for any $B$
#
# $B^TB$ is always symmetric, so any non-symmetric $A$ satisfy
#
# What matrix has orthogonal eigenvectors but not symmetric
#
# Matrix that skew symmetry
